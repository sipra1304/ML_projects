# %% [markdown]
# <a href="https://colab.research.google.com/github/sipra1304/ML_projects/blob/main/TEXTSUMMARIZATION_USING_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
# !nltk.download('stopwords')
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `'stopwords''
# /bin/bash: -c: line 1: `nltk.download('stopwords')'

# %%
import nltk
import string
from heapq import nlargest

# %%
with open("machine.txt","r", encoding="utf8") as f:
    text=f.read()

# %%
print(text)
# Out:
# One of the primary advantages of online classes is the flexibility they offer in terms of scheduling. Traditional classes often require students to adhere to a fixed schedule, attending lectures at specific times on certain days. This can be challenging for individuals who have work commitments, family responsibilities, or other time constraints. Online classes, on the other hand, allow students to access course materials and participate in discussions at their own pace and at times that suit their personal schedules.
#
#
# A notable drawback of online classes is the time-delayed interaction between teachers and students. In a traditional classroom setting, students can ask questions and receive immediate clarification. In an online environment, communication is often asynchronous, with students submitting questions via email or discussion boards and waiting for the instructor's response. This can create a sense of detachment and may hinder the spontaneity of discussions that occur in face-to-face classrooms.
#
#
# In traditional classes, students can build relationships with their peers through face-to-face interactions, group projects, and casual conversations. Online classes, however, often rely on written communication through emails or online forums. This can result in a less personal connection among classmates, as the nuances of non-verbal communication are limited, and the sense of a shared physical space is absent.
#
#
# Online classes often rely on instructional methods such as videos, electronic articles, and other digital resources. While these can be effective, they may lack the hands-on experiences and practical applications that traditional classes can offer. For instance, subjects like science or art may require physical demonstrations or experiments that are challenging to replicate in an online setting. This limitation can impact the depth of understanding and the development of practical skills.
#
# In conclusion, while online classes provide unparalleled flexibility in scheduling, they come with trade-offs in terms of delayed interaction, limited personal connections among classmates, and constraints in instructional methods. The choice between online and traditional classes depends on individual preferences, learning styles, and the specific requirements of the course or program.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

#print(STOPWORDS)
print("there are {} words in all text.". format(len(text)))

WC=WordCloud(stopwords=STOPWORDS, background_color="black").generate(text)

plt.figure(figsize=(20,10))
plt.imshow(WC,interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# there are 2327 words in all text.

# %%
# !pip install rake_nltk
# Out:
# Requirement already satisfied: rake_nltk in /usr/local/lib/python3.10/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from rake_nltk) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.66.1)

# %%
# !pip install nltk
# !nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# /bin/bash: -c: line 1: syntax error near unexpected token `'stopwords''
# /bin/bash: -c: line 1: `nltk.download('stopwords')'

# %%
# !pip install rake_nltk
# Out:
# Requirement already satisfied: rake_nltk in /usr/local/lib/python3.10/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from rake_nltk) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.66.1)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.corpus.stopwords.words()
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
#  'ذا',
#  'ذات',
#  'ذاك',
#  'ذان',
#  'ذانك',
#  'ذلك',
#  'ذلكم',
#  'ذلكما',
#  'ذلكن',
#  'ذه',
#  'ذو',
#  'ذوا',
#  'ذواتا',
#  'ذواتي',
#  'ذي',
#  'ذين',
#  'ذينك',
#  'ريث',
#  'سوف',
#  'سوى',
#  'شتان',
#  'عدا',
#  'عسى',
#  'عل',
#  'على',
#  'عليك',
#  'عليه',
#  'عما',
#  'عن',
#  'عند',
#  'غير',
#  'فإذا',
#  'فإن',
#  'فلا',
#  'فمن',
#  'في',
#  'فيم',
#  'فيما',
#  'فيه',
#  'فيها',
#  'قد',
#  'كأن',
#  'كأنما',
#  'كأي',
#  'كأين',
#  'كذا',
#  'كذلك',
#  'كل',
#  'كلا',
#  'كلاهما',
#  'كلتا',
#  'كلما',
#  'كليكما',
#  'كليهما',
#  'كم',
#  'كم',
#  'كما',
#  'كي',
#  'كيت',
#  'كيف',
#  'كيفما',
#  'لا',
#  'لاسيما',
#  'لدى',
#  'لست',
#  'لستم',
#  'لستما',
#  'لستن',
#  'لسن',
#  'لسنا',
#  'لعل',
#  'لك',
#  'لكم',
#  'لكما',
#  'لكن',
#  'لكنما',
#  'لكي',
#  'لكيلا',
#  'لم',
#  'لما',
#  'لن',
#  'لنا',
#  'له',
#  'لها',
#  'لهم',
#  'لهما',
#  'لهن',
#  'لو',
#  'لولا',
#  'لوما',
#  'لي',
#  'لئن',
#  'ليت',
#  'ليس',
#  'ليسا',
#  'ليست',
#  'ليستا',
#  'ليسوا',
#  'ما',
#  'ماذا',
#  'متى',
#  'مذ',
#  'مع',
#  'مما',
#  'ممن',
#  'من',
#  'منه',
#  'منها',
#  'منذ',
#  'مه',
#  'مهما',
#  'نحن',
#  'نحو',
#  'نعم',
#  'ها',
#  'هاتان',
#  'هاته',
#  'هاتي',
#  'هاتين',
#  'هاك',
#  'هاهنا',
#  'هذا',
#  'هذان',
#  'هذه',
#  'هذي',
#  'هذين',
#  'هكذا',
#  'هل',
#  'هلا',
#  'هم',
#  'هما',
#  'هن',
#  'هنا',
#  'هناك',
#  'هنالك',
#  'هو',
#  'هؤلاء',
#  'هي',
#  'هيا',
#  'هيت',
#  'هيهات',
#  'والذي',
#  'والذين',
#  'وإذ',
#  'وإذا',
#  'وإن',
#  'ولا',
#  'ولكن',
#  'ولو',
#  'وما',
#  'ومن',
#  'وهو',
#  'يا',
#  'أبٌ',
#  'أخٌ',
#  'حمٌ',
#  'فو',
#  'أنتِ',
#  'يناير',
#  'فبراير',
#  'مارس',
#  'أبريل',
#  'مايو',
#  'يونيو',
#  'يوليو',
#  'أغسطس',
#  'سبتمبر',
#  'أكتوبر',
#  'نوفمبر',
#  'ديسمبر',
#  'جانفي',
#  'فيفري',
#  'مارس',
#  'أفريل',
#  'ماي',
#  'جوان',
#  'جويلية',
#  'أوت',
#  'كانون',
#  'شباط',
#  'آذار',
#  'نيسان',
#  'أيار',
#  'حزيران',
#  'تموز',
#  'آب',
#  'أيلول',
#  'تشرين',
#  'دولار',
#  'دينار',
#  'ريال',
#  'درهم',
#  'ليرة',
#  'جنيه',
#  'قرش',
#  'مليم',
#  'فلس',
#  'هللة',
#  'سنتيم',
#  'يورو',
#  'ين',
#  'يوان',
#  'شيكل',
#  'واحد',
#  'اثنان',
#  'ثلاثة',
#  'أربعة',
#  'خمسة',
#  'ستة',
#  'سبعة',
#  'ثمانية',
#  'تسعة',
#  'عشرة',
#  'أحد',
#  'اثنا',
#  'اثني',
#  'إحدى',
#  'ثلاث',
#  'أربع',
#  'خمس',
#  'ست',
#  'سبع',
#  'ثماني',
#  'تسع',
#  'عشر',
#  'ثمان',
#  'سبت',
#  'أحد',
#  'اثنين',
#  'ثلاثاء',
#  'أربعاء',
#  'خميس',
#  'جمعة',
#  'أول',
#  'ثان',
#  'ثاني',
#  'ثالث',
#  'رابع',
#  'خامس',
#  'سادس',
#  'سابع',
#  'ثامن',
#  'تاسع',
#  'عاشر',
#  'حادي',
#  'أ',
#  'ب',
#  'ت',
#  'ث',
#  'ج',
#  'ح',
#  'خ',
#  'د',
#  'ذ',
#  'ر',
#  'ز',
#  'س',
#  'ش',
#  'ص',
#  'ض',
#  'ط',
#  'ظ',
#  'ع',
#  'غ',
#  'ف',
#  'ق',
#  'ك',
#  'ل',
#  'م',
#  'ن',
#  'ه',
#  'و',
#  'ي',
#  'ء',
#  'ى',
#  'آ',
#  'ؤ',
#  'ئ',
#  'أ',
#  'ة',
#  'ألف',
#  'باء',
#  'تاء',
#  'ثاء',
#  'جيم',
#  'حاء',
#  'خاء',
#  'دال',
#  'ذال',
#  'راء',
#  'زاي',
#  'سين',
#  'شين',
#  'صاد',
#  'ضاد',
#  'طاء',
#  'ظاء',
#  'عين',
#  'غين',
#  'فاء',
#  'قاف',
#  'كاف',
#  'لام',
#  'ميم',
#  'نون',
#  'هاء',
#  'واو',
#  'ياء',
#  'همزة',
#  'ي',
#  'نا',
#  'ك',
#  'كن',
#  'ه',
#  'إياه',
#  'إياها',
#  'إياهما',
#  'إياهم',
#  'إياهن',
#  'إياك',
#  'إياكما',
#  'إياكم',
#  'إياك',
#  'إياكن',
#  'إياي',
#  'إيانا',
#  'أولالك',
#  'تانِ',
#  'تانِك',
#  'تِه',
#  'تِي',
#  'تَيْنِ',
#  'ثمّ',
#  'ثمّة',
#  'ذانِ',
#  'ذِه',
#  'ذِي',
#  'ذَيْنِ',
#  'هَؤلاء',
#  'هَاتانِ',
#  'هَاتِه',
#  'هَاتِي',
#  'هَاتَيْنِ',
#  'هَذا',
#  'هَذانِ',
#  'هَذِه',
#  'هَذِي',
#  'هَذَيْنِ',
#  'الألى',
#  'الألاء',
#  'أل',
#  'أنّى',
#  'أيّ',
#  'ّأيّان',
#  'أنّى',
#  'أيّ',
#  'ّأيّان',
#  'ذيت',
#  'كأيّ',
#  'كأيّن',
#  'بضع',
#  'فلان',
#  'وا',
#  'آمينَ',
#  'آهِ',
#  'آهٍ',
#  'آهاً',
#  'أُفٍّ',
#  'أُفٍّ',
#  'أفٍّ',
#  'أمامك',
#  'أمامكَ',
#  'أوّهْ',
#  'إلَيْكَ',
#  'إلَيْكَ',
#  'إليكَ',
#  'إليكنّ',
#  'إيهٍ',
#  'بخٍ',
#  'بسّ',
#  'بَسْ',
#  'بطآن',
#  'بَلْهَ',
#  'حاي',
#  'حَذارِ',
#  'حيَّ',
#  'حيَّ',
#  'دونك',
#  'رويدك',
#  'سرعان',
#  'شتانَ',
#  'شَتَّانَ',
#  'صهْ',
#  'صهٍ',
#  'طاق',
#  'طَق',
#  'عَدَسْ',
#  'كِخ',
#  'مكانَك',
#  'مكانَك',
#  'مكانَك',
#  'مكانكم',
#  'مكانكما',
#  'مكانكنّ',
#  'نَخْ',
#  'هاكَ',
#  'هَجْ',
#  'هلم',
#  'هيّا',
#  'هَيْهات',
#  'وا',
#  'واهاً',
#  'وراءَك',
#  'وُشْكَانَ',
#  'وَيْ',
#  'يفعلان',
#  'تفعلان',
#  'يفعلون',
#  'تفعلون',
#  'تفعلين',
#  'اتخذ',
#  'ألفى',
#  'تخذ',
#  'ترك',
#  'تعلَّم',
#  'جعل',
#  'حجا',
#  'حبيب',
#  'خال',
#  'حسب',
#  'خال',
#  'درى',
#  'رأى',
#  'زعم',
#  'صبر',
#  'ظنَّ',
#  'عدَّ',
#  'علم',
#  'غادر',
#  'ذهب',
#  'وجد',
#  'ورد',
#  'وهب',
#  'أسكن',
#  'أطعم',
#  'أعطى',
#  'رزق',
#  'زود',
#  'سقى',
#  'كسا',
#  'أخبر',
#  'أرى',
#  'أعلم',
#  'أنبأ',
#  'حدَث',
#  'خبَّر',
#  'نبَّا',
#  'أفعل به',
#  'ما أفعله',
#  'بئس',
#  'ساء',
#  'طالما',
#  'قلما',
#  'لات',
#  'لكنَّ',
#  'ءَ',
#  'أجل',
#  'إذاً',
#  'أمّا',
#  'إمّا',
#  'إنَّ',
#  'أنًّ',
#  'أى',
#  'إى',
#  'أيا',
#  'ب',
#  'ثمَّ',
#  'جلل',
#  'جير',
#  'رُبَّ',
#  'س',
#  'علًّ',
#  'ف',
#  'كأنّ',
#  'كلَّا',
#  'كى',
#  'ل',
#  'لات',
#  'لعلَّ',
#  'لكنَّ',
#  'لكنَّ',
#  'م',
#  'نَّ',
#  'هلّا',
#  'وا',
#  'أل',
#  'إلّا',
#  'ت',
#  'ك',
#  'لمّا',
#  'ن',
#  'ه',
#  'و',
#  'ا',
#  'ي',
#  'تجاه',
#  'تلقاء',
#  'جميع',
#  'حسب',
#  'سبحان',
#  'شبه',
#  'لعمر',
#  'مثل',
#  'معاذ',
#  'أبو',
#  'أخو',
#  'حمو',
#  'فو',
#  'مئة',
#  'مئتان',
#  'ثلاثمئة',
#  'أربعمئة',
#  'خمسمئة',
#  'ستمئة',
#  'سبعمئة',
#  'ثمنمئة',
#  'تسعمئة',
#  'مائة',
#  'ثلاثمائة',
#  'أربعمائة',
#  'خمسمائة',
#  'ستمائة',
#  'سبعمائة',
#  'ثمانمئة',
#  'تسعمائة',
#  'عشرون',
#  'ثلاثون',
#  'اربعون',
#  'خمسون',
#  'ستون',
#  'سبعون',
#  'ثمانون',
#  'تسعون',
#  'عشرين',
#  'ثلاثين',
#  'اربعين',
#  'خمسين',
#  'ستين',
#  'سبعين',
#  'ثمانين',
#  'تسعين',
#  'بضع',
#  'نيف',
#  'أجمع',
#  'جميع',
#  'عامة',
#  'عين',
#  'نفس',
#  'لا سيما',
#  'أصلا',
#  'أهلا',
#  'أيضا',
#  'بؤسا',
#  'بعدا',
#  'بغتة',
#  'تعسا',
#  'حقا',
#  'حمدا',
#  'خلافا',
#  'خاصة',
#  'دواليك',
#  'سحقا',
#  'سرا',
#  'سمعا',
#  'صبرا',
#  'صدقا',
#  'صراحة',
#  'طرا',
#  'عجبا',
#  'عيانا',
#  'غالبا',
#  'فرادى',
#  'فضلا',
#  'قاطبة',
#  'كثيرا',
#  'لبيك',
#  'معاذ',
#  'أبدا',
#  'إزاء',
#  'أصلا',
#  'الآن',
#  'أمد',
#  'أمس',
#  'آنفا',
#  'آناء',
#  'أنّى',
#  'أول',
#  'أيّان',
#  'تارة',
#  'ثمّ',
#  'ثمّة',
#  'حقا',
#  'صباح',
#  'مساء',
#  'ضحوة',
#  'عوض',
#  'غدا',
#  'غداة',
#  'قطّ',
#  'كلّما',
#  'لدن',
#  'لمّا',
#  'مرّة',
#  'قبل',
#  'خلف',
#  'أمام',
#  'فوق',
#  'تحت',
#  'يمين',
#  'شمال',
#  'ارتدّ',
#  'استحال',
#  'أصبح',
#  'أضحى',
#  'آض',
#  'أمسى',
#  'انقلب',
#  'بات',
#  'تبدّل',
#  'تحوّل',
#  'حار',
#  'رجع',
#  'راح',
#  'صار',
#  'ظلّ',
#  'عاد',
#  'غدا',
#  'كان',
#  'ما انفك',
#  'ما برح',
#  'مادام',
#  'مازال',
#  'مافتئ',
#  'ابتدأ',
#  'أخذ',
#  'اخلولق',
#  'أقبل',
#  'انبرى',
#  'أنشأ',
#  'أوشك',
#  'جعل',
#  'حرى',
#  'شرع',
#  'طفق',
#  'علق',
#  'قام',
#  'كرب',
#  'كاد',
#  'هبّa',
#  'ad',
#  'altı',
#  'altmış',
#  'amma',
#  'arasında',
#  'artıq',
#  'ay',
#  'az',
#  'bax',
#  'belə',
#  'bəli',
#  'bəlkə',
#  'beş',
#  'bəy',
#  'bəzən',
#  'bəzi',
#  'bilər',
#  'bir',
#  'biraz',
#  'biri',
#  'birşey',
#  'biz',
#  'bizim',
#  'bizlər',
#  'bu',
#  'buna',
#  'bundan',
#  'bunların',
#  'bunu',
#  'bunun',
#  'buradan',
#  'bütün',
#  'ci',
#  'cı',
#  'çox',
#  'cu',
#  'cü',
#  'çünki',
#  'da',
#  'daha',
#  'də',
#  'dedi',
#  'dək',
#  'dən',
#  'dəqiqə',
#  'deyil',
#  'dir',
#  'doqquz',
#  'doqsan',
#  'dörd',
#  'düz',
#  'ə',
#  'edən',
#  'edir',
#  'əgər',
#  'əlbəttə',
#  'elə',
#  'əlli',
#  'ən',
#  'əslində',
#  'et',
#  'etdi',
#  'etmə',
#  'etmək',
#  'faiz',
#  'gilə',
#  'görə',
#  'ha',
#  'haqqında',
#  'harada',
#  'hə',
#  'heç',
#  'həm',
#  'həmin',
#  'həmişə',
#  'hər',
#  'ı',
#  'idi',
#  'iki',
#  'il',
#  'ildə',
#  'ilə',
#  'ilk',
#  'in',
#  'indi',
#  'isə',
#  'istifadə',
#  'iyirmi',
#  'ki',
#  'kim',
#  'kimə',
#  'kimi',
#  'lakin',
#  'lap',
#  'məhz',
#  'mən',
#  'mənə',
#  'mirşey',
#  'nə',
#  'nəhayət',
#  'niyə',
#  'o',
#  'obirisi',
#  'of',
#  'olan',
#  'olar',
#  'olaraq',
#  'oldu',
#  'olduğu',
#  'olmadı',
#  'olmaz',
#  'olmuşdur',
#  'olsun',
#  'olur',
#  'on',
#  'ona',
#  'ondan',
#  'onlar',
#  'onlardan',
#  'onların ',
#  'onsuzda',
#  'onu',
#  'onun',
#  'oradan',
#  'otuz',
#  'öz',
#  'özü',
#  'qarşı',
#  'qədər',
#  'qırx',
#  'saat',
#  'sadəcə',
#  'saniyə',
#  'səhv',
#  'səkkiz',
#  'səksən',
#  'sən',
#  'sənə',
#  'sənin',
#  'siz',
#  'sizin',
#  'sizlər',
#  'sonra',
#  'təəssüf',
#  'ü',
#  'üç',
#  'üçün',
#  'var',
#  'və',
#  'xan',
#  'xanım',
#  'xeyr',
#  'ya',
#  'yalnız',
#  'yaxşı',
#  'yeddi',
#  'yenə',
#  'yəni',
#  'yetmiş',
#  'yox',
#  'yoxdur',
#  'yoxsa',
#  'yüz',
#  'zamanahala',
#  'aitzitik',
#  'al',
#  'ala ',
#  'alabadere',
#  'alabaina',
#  'alabaina',
#  'aldiz ',
#  'alta',
#  'amaitu',
#  'amaitzeko',
#  'anitz',
#  'antzina',
#  'arabera',
#  'arabera',
#  'arabera',
#  'argi',
#  'arratsaldero',
#  'arte',
#  'artean',
#  'asko',
#  'aspaldiko',
#  'aurrera',
#  'aurrera',
#  'azkenez',
#  'azkenik',
#  'azkenik',
#  'ba',
#  'bada',
#  'bada ',
#  'bada ',
#  'bada ',
#  'badarik',
#  'badarik',
#  'badarik ',
#  'badere',
#  'bai',
#  'baina',
#  'baina',
#  'baina ',
#  'baino',
#  'baino',
#  'baino',
#  'baino',
#  'baita',
#  'baizik ',
#  'baldin',
#  'baldin',
#  'barren',
#  'bat',
#  'batean',
#  'batean',
#  'batean',
#  'batean',
#  'batek',
#  'baten',
#  'batera',
#  'batez',
#  'bati',
#  'batzuei',
#  'batzuek',
#  'batzuetan',
#  'batzuk',
#  'bazen',
#  'bederen',
#  'bederik',
#  'beharrez',
#  'behiala',
#  'behin',
#  'behin',
#  'behin',
#  'behin',
#  'behinik',
#  'behinola',
#  'behintzat',
#  'bera',
#  'beraiek',
#  'beranduago',
#  'berau',
#  'berauek',
#  'beraz',
#  'beraz ',
#  'bere',
#  ...]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
# !pip install nltk punkt
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# ERROR: Could not find a version that satisfies the requirement punkt (from versions: none)
# ERROR: No matching distribution found for punkt

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from rake_nltk import Rake
rk=Rake()

rk.extract_keywords_from_text(text)
extract_keyword=rk.get_ranked_phrases()
extract_keyword
# Out:
# ['less personal connection among classmates',
#  'limited personal connections among classmates',
#  'art may require physical demonstrations',
#  'students submitting questions via email',
#  'online classes provide unparalleled flexibility',
#  'traditional classes often require students',
#  'online classes often rely',
#  'shared physical space',
#  'subjects like science',
#  'receive immediate clarification',
#  'traditional classes depends',
#  'traditional classroom setting',
#  'access course materials',
#  'often rely',
#  'personal schedules',
#  'traditional classes',
#  'traditional classes',
#  'ask questions',
#  'online classes',
#  'online classes',
#  'online classes',
#  'online classes',
#  'often asynchronous',
#  'may lack',
#  'may hinder',
#  'online setting',
#  'allow students',
#  'online forums',
#  'online environment',
#  'work commitments',
#  'specific requirements',
#  'primary advantages',
#  'practical skills',
#  'practical applications',
#  'notable drawback',
#  'learning styles',
#  'instructional methods',
#  'instructional methods',
#  'individual preferences',
#  'group projects',
#  'fixed schedule',
#  'family responsibilities',
#  'electronic articles',
#  'discussion boards',
#  'digital resources',
#  'delayed interaction',
#  'delayed interaction',
#  'certain days',
#  'casual conversations',
#  'build relationships',
#  'attending lectures',
#  'written communication',
#  'verbal communication',
#  'specific times',
#  'face interactions',
#  'face classrooms',
#  'time constraints',
#  'limited',
#  'flexibility',
#  'students',
#  'students',
#  'students',
#  'online',
#  'course',
#  'communication',
#  'times',
#  'time',
#  'face',
#  'face',
#  'constraints',
#  'waiting',
#  'videos',
#  'understanding',
#  'trade',
#  'terms',
#  'terms',
#  'teachers',
#  'suit',
#  'spontaneity',
#  'sense',
#  'sense',
#  'scheduling',
#  'scheduling',
#  'result',
#  'response',
#  'replicate',
#  'program',
#  'peers',
#  'participate',
#  'pace',
#  'one',
#  'offs',
#  'offer',
#  'offer',
#  'occur',
#  'nuances',
#  'non',
#  'limitation',
#  'instructor',
#  'instance',
#  'individuals',
#  'impact',
#  'however',
#  'hands',
#  'hand',
#  'experiments',
#  'experiences',
#  'emails',
#  'effective',
#  'discussions',
#  'discussions',
#  'development',
#  'detachment',
#  'depth',
#  'create',
#  'conclusion',
#  'come',
#  'choice',
#  'challenging',
#  'challenging',
#  'adhere',
#  'absent']

# %% [markdown]
# #text summarization

# %%
print(text.count("."))
print(string.punctuation)
nopuch=[char for char in text if char not in string.punctuation]
nopuch="".join(nopuch)
#print(nopuch)
# Out:
# 17
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
process_text=[word for word in nopuch.split() if word.lower() not in nltk.corpus.stopwords.words('english')]
#print(process_text)

# %%
#create word freq
word_freq={}
for word in process_text:
    if word not in word_freq:
        word_freq[word]=1
    else:
        word_freq[word]=word_freq[word]+1

#dict(sorted(word_freq.items(),key=lambda item:item[1], reverse=True))

max_freq=max(word_freq.values())

for word in word_freq.keys():
    word_freq[word]=(word_freq[word]/max_freq)

#create sent freq
sent_list=nltk.sent_tokenize(text)

sent_score={}
for sent in sent_list:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent]=word_freq[word]
            else:
                sent_score[sent]=sent_score[sent]+word_freq[word]

# %%
#dict(sorted(sent_score.items(),key=lambda item:item[1], reverse=True))

summary_sent=nlargest(3,sent_score, key=sent_score.get)

summary=" ".join(summary_sent)

summary
# Out:
# 'In conclusion, while online classes provide unparalleled flexibility in scheduling, they come with trade-offs in terms of delayed interaction, limited personal connections among classmates, and constraints in instructional methods. Online classes, on the other hand, allow students to access course materials and participate in discussions at their own pace and at times that suit their personal schedules. Traditional classes often require students to adhere to a fixed schedule, attending lectures at specific times on certain days.'
